# %%
using D4M

# %%
using SparseArrays
A = ReadJLD("graphclassdata/A.jld");

# %%
A2 = deepcopy(A)
# Out:
# Assoc(Union{AbstractString, Number}["100000631369781733", "100215234818781733", "100255788699781733", "100257058747781733", "100259101320881733", "100270918609781733", "100468043090881733", "100614883768781733", "100675061530881733", "100802836807781733"  …  "990062652619781733", "990089437448781733", "994012704516781733", "994090263869781733", "996506234539781733", "996795392538781733", "996901203830881733", "996943631007781733", "998232942778781733", "998694085160881733"], Union{AbstractString, Number}["latlon|++000049..07322283290000000000", "latlon|++000063..41692952220000000000", "latlon|++000063..43942779527633360000", "latlon|++000063..43984350160000000000", "latlon|++000063..53752449318133000000", "latlon|++000063..62071528205060500000", "latlon|++000063..63030496010000000000", "latlon|++000063..63512104020000000000", "latlon|++000067..44395266960000000000", "latlon|++000075..21584991845454000000"  …  "word|~\"@melindaapriyani:", "word|~\"@rbeccapuspa:", "word|~(???)~", "word
# ...

# %%
A3=deepcopy(A)
# Out:
# Assoc(Union{AbstractString, Number}["100000631369781733", "100215234818781733", "100255788699781733", "100257058747781733", "100259101320881733", "100270918609781733", "100468043090881733", "100614883768781733", "100675061530881733", "100802836807781733"  …  "990062652619781733", "990089437448781733", "994012704516781733", "994090263869781733", "996506234539781733", "996795392538781733", "996901203830881733", "996943631007781733", "998232942778781733", "998694085160881733"], Union{AbstractString, Number}["latlon|++000049..07322283290000000000", "latlon|++000063..41692952220000000000", "latlon|++000063..43942779527633360000", "latlon|++000063..43984350160000000000", "latlon|++000063..53752449318133000000", "latlon|++000063..62071528205060500000", "latlon|++000063..63030496010000000000", "latlon|++000063..63512104020000000000", "latlon|++000067..44395266960000000000", "latlon|++000075..21584991845454000000"  …  "word|~\"@melindaapriyani:", "word|~\"@rbeccapuspa:", "word|~(???)~", "word
# ...
